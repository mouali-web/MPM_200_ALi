# %% [markdown]
# <a href="https://colab.research.google.com/github/mouali-web/MPM_200_ALi/blob/main/Session%209/database_management_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# pip install pandas

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/covid-tracking-data-master_COVID_Tracking_Project_2020_08_07_daily.csv')

# %%
df.head()
# Out:
#        date state  positive  negative  pending  hospitalizedCurrently  \
# 0  20200807    AK    4288.0  264563.0      NaN                   37.0
# 1  20200807    AL   98301.0  651115.0      NaN                 1575.0
# 2  20200807    AR   48039.0  503484.0      NaN                  514.0
# 3  20200807    AS       0.0    1396.0      NaN                    NaN
# 4  20200807    AZ  185053.0  819792.0      NaN                 1772.0
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                     NaN             NaN              NaN
# 1                 11537.0             NaN           1219.0
# 2                  3168.0             NaN              NaN
# 3                     NaN             NaN              NaN
# 4                 19241.0           565.0              NaN
#
#    onVentilatorCurrently  ...   posNeg  deathIncrease hospitalizedIncrease  \
# 0                    3.0  ...   268851              0                    0
# ...

# %%
df.head(10)
# Out:
#        date state  positive   negative  pending  hospitalizedCurrently  \
# 0  20200807    AK    4288.0   264563.0      NaN                   37.0
# 1  20200807    AL   98301.0   651115.0      NaN                 1575.0
# 2  20200807    AR   48039.0   503484.0      NaN                  514.0
# 3  20200807    AS       0.0     1396.0      NaN                    NaN
# 4  20200807    AZ  185053.0   819792.0      NaN                 1772.0
# 5  20200807    CA  538416.0  8058466.0      NaN                 7277.0
# 6  20200807    CO   49436.0   521927.0      NaN                  317.0
# 7  20200807    CT   50320.0   814313.0      NaN                   65.0
# 8  20200807    DC   12589.0   196136.0      NaN                   90.0
# 9  20200807    DE   15445.0   179339.0      NaN                   37.0
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                     NaN             NaN              NaN
# 1                 11537.0             NaN           1219.0
# ...

# %%
df.columns.tolist()
# Out:
# ['date',
#  'state',
#  'positive',
#  'negative',
#  'pending',
#  'hospitalizedCurrently',
#  'hospitalizedCumulative',
#  'inIcuCurrently',
#  'inIcuCumulative',
#  'onVentilatorCurrently',
#  'onVentilatorCumulative',
#  'recovered',
#  'dataQualityGrade',
#  'lastUpdateEt',
#  'dateModified',
#  'checkTimeEt',
#  'death',
#  'hospitalized',
#  'dateChecked',
#  'totalTestsViral',
#  'positiveTestsViral',
#  'negativeTestsViral',
#  'positiveCasesViral',
#  'deathConfirmed',
#  'deathProbable',
#  'fips',
#  'positiveIncrease',
#  'negativeIncrease',
#  'total',
#  'totalTestResults',
#  'totalTestResultsIncrease',
#  'posNeg',
#  'deathIncrease',
#  'hospitalizedIncrease',
#  'hash',
#  'commercialScore',
#  'negativeRegularScore',
#  'negativeScore',
#  'positiveScore',
#  'score',
#  'grade']

# %%
df.columns.to_list()
# Out:
# ['date',
#  'state',
#  'positive',
#  'negative',
#  'pending',
#  'hospitalizedCurrently',
#  'hospitalizedCumulative',
#  'inIcuCurrently',
#  'inIcuCumulative',
#  'onVentilatorCurrently',
#  'onVentilatorCumulative',
#  'recovered',
#  'dataQualityGrade',
#  'lastUpdateEt',
#  'dateModified',
#  'checkTimeEt',
#  'death',
#  'hospitalized',
#  'dateChecked',
#  'totalTestsViral',
#  'positiveTestsViral',
#  'negativeTestsViral',
#  'positiveCasesViral',
#  'deathConfirmed',
#  'deathProbable',
#  'fips',
#  'positiveIncrease',
#  'negativeIncrease',
#  'total',
#  'totalTestResults',
#  'totalTestResultsIncrease',
#  'posNeg',
#  'deathIncrease',
#  'hospitalizedIncrease',
#  'hash',
#  'commercialScore',
#  'negativeRegularScore',
#  'negativeScore',
#  'positiveScore',
#  'score',
#  'grade']

# %%
df.dtypes
# Out:
# date                          int64
# state                        object
# positive                    float64
# negative                    float64
# pending                     float64
# hospitalizedCurrently       float64
# hospitalizedCumulative      float64
# inIcuCurrently              float64
# inIcuCumulative             float64
# onVentilatorCurrently       float64
# onVentilatorCumulative      float64
# recovered                   float64
# dataQualityGrade             object
# lastUpdateEt                 object
# dateModified                 object
# checkTimeEt                  object
# death                       float64
# hospitalized                float64
# dateChecked                  object
# totalTestsViral             float64
# positiveTestsViral          float64
# negativeTestsViral          float64
# positiveCasesViral          float64
# deathConfirmed              float64
# deathProbable               float64
# fips                          int64
# ...

# %%
CA = df[df.state == 'CA']

# %%
CA
# Out:
#           date state  positive   negative  pending  hospitalizedCurrently  \
# 5     20200807    CA  538416.0  8058466.0      NaN                 7277.0
# 61    20200806    CA  529980.0  7970483.0      NaN                 7485.0
# 117   20200805    CA  524722.0  7884678.0      NaN                 7552.0
# 173   20200804    CA  519427.0  7786286.0      NaN                 7630.0
# 229   20200803    CA  514901.0  7669795.0      NaN                 7629.0
# ...        ...   ...       ...        ...      ...                    ...
# 8478  20200308    CA      88.0      462.0      NaN                    NaN
# 8528  20200307    CA      69.0      462.0      NaN                    NaN
# 8577  20200306    CA      60.0      462.0      NaN                    NaN
# 8611  20200305    CA      53.0      462.0      NaN                    NaN
# 8635  20200304    CA      53.0      462.0      NaN                    NaN
#
#       hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# ...

# %%
CA[["total", "totalTestResults", "totalTestResultsIncrease", "positiveIncrease", 'positive']]
# Out:
#         total  totalTestResults  totalTestResultsIncrease  positiveIncrease  \
# 5     8596882           8596882                     96419              8436
# 61    8500463           8500463                     91063              5258
# 117   8409400           8409400                    103687              5295
# 173   8305713           8305713                    121017              4526
# 229   8184696           8184696                    148721              5739
# ...       ...               ...                       ...               ...
# 8478      550               550                        19                19
# 8528      531               531                         9                 9
# 8577      522               522                         7                 7
# 8611      515               515                         0                 0
# 8635      515               515                         0                 0
#
#       positive
# 5     538416.0
# 61    529980.0
# ...

# %%
CA.positiveIncrease.sum()
# Out:
# np.int64(538363)

# %%
CA.positiveIncrease.median()
# Out:
# 2140.0

# %%
CA.positiveIncrease.describe()
# Out:
# count      157.000000
# mean      3429.063694
# std       3186.729975
# min          0.000000
# 25%       1179.000000
# 50%       2140.000000
# 75%       5349.000000
# max      12807.000000
# Name: positiveIncrease, dtype: float64

# %%
CA.describe()
# Out:
#                date       positive      negative       pending  \
# count  1.570000e+02     157.000000  1.570000e+02     28.000000
# mean   2.020053e+07  145420.847134  2.266188e+06  29110.714286
# std    1.495979e+02  156042.275399  2.417328e+06  22975.193374
# min    2.020030e+07      53.000000  4.620000e+02   7200.000000
# 25%    2.020041e+07   21794.000000  1.685340e+05  13200.000000
# 50%    2.020052e+07   86197.000000  1.334930e+06  14100.000000
# 75%    2.020063e+07  219252.000000  3.842440e+06  57400.000000
# max    2.020081e+07  538416.000000  8.058466e+06  64400.000000
#
#        hospitalizedCurrently  hospitalizedCumulative  inIcuCurrently  \
# count             134.000000                     0.0      134.000000
# mean             5340.656716                     NaN     1527.000000
# std              1936.099700                     NaN      422.260423
# min               746.000000                     NaN      200.000000
# ...

# %%
df.groupby("state").agg({"positiveIncrease":'sum'})
# Out:
#        positiveIncrease
# state
# AK                 4288
# AL                98301
# AR                48039
# AS                    0
# AZ               185051
# CA               538363
# CO                49436
# CT                50320
# DC                12589
# DE                15445
# FL               518073
# GA               209002
# GU                  408
# HI                 2913
# IA                47865
# ID                23399
# IL               191804
# IN                72253
# KS                30638
# KY                33796
# LA               128746
# MA               120283
# MD                93806
# ME                 4014
# MI                95461
# MN                59184
# MO                57379
# MP                   47
# MS                65436
# MT                 4757
# NC               132811
# ND                 7327
# NE                27821
# NH                 6740
# NJ               184060
# NM                21773
# NV                54532
# ...

# %%
df.groupby('state').agg({'positiveIncrease':'sum','totalTestResultsIncrease':'mean'})
# Out:
#        positiveIncrease  totalTestResultsIncrease
# state
# AK                 4288               1734.470968
# AL                98301               4866.337662
# AR                48039               3558.174194
# AS                    0                  9.627586
# AZ               185051               6400.101911
# CA               538363              54753.929936
# CO                49436               3662.461538
# CT                50320               5614.500000
# DC                12589               1337.942308
# DE                15445               1256.606452
# FL               518073              24821.101911
# GA               209002              11166.414013
# GU                  408                167.834483
# HI                 2913                878.461039
# IA                47865               3281.838710
# ID                23399               1290.084416
# IL               191804              19017.770701
# IN                72253               5271.632258
# ...

# %%
#filtering for one row df[0:1]

# %%
df[50:60]
# Out:
#         date state  positive  negative  pending  hospitalizedCurrently  \
# 50  20200807    VI     522.0    9977.0     21.0                    NaN
# 51  20200807    VT    1448.0   99514.0      NaN                    6.0
# 52  20200807    WA   60917.0  950107.0      NaN                  405.0
# 53  20200807    WI   63028.0  974948.0    118.0                  296.0
# 54  20200807    WV    7433.0  305244.0      NaN                  122.0
# 55  20200807    WY    3000.0   53625.0      NaN                   17.0
# 56  20200806    AK    4223.0  257349.0      NaN                   42.0
# 57  20200806    AL   96592.0  643192.0      NaN                 1575.0
# 58  20200806    AR   47028.0  492808.0      NaN                  514.0
# 59  20200806    AS       0.0    1396.0      NaN                    NaN
#
#     hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 50                     NaN             NaN              NaN
# 51                     NaN             NaN              NaN
# ...

# %% [markdown]
# ## Population of states

# %%
# Merging data together

# %%
states = pd.read_excel("/content/NST-EST2023-POP.xlsx")

# %%
states.head()
# Out:
#            state    current       2020       2021       2022       2023
# 0  United States  331464948  331526933  332048977  333271411  334914895
# 1      Northeast   57614141   57430477   57243423   57026847   56983517
# 2        Midwest   68987296   68969794   68850246   68783028   68909283
# 3          South  126268529  126465281  127353282  128702030  130125290
# 4           West   78594982   78661381   78602026   78759506   78896805

# %%
#renaming the columns

# %%
states.columns = ['state', 'current', '2020', '2021', '2022', '2023']
states.head()
# Out:
#            state    current       2020       2021       2022       2023
# 0  United States  331464948  331526933  332048977  333271411  334914895
# 1      Northeast   57614141   57430477   57243423   57026847   56983517
# 2        Midwest   68987296   68969794   68850246   68783028   68909283
# 3          South  126268529  126465281  127353282  128702030  130125290
# 4           West   78594982   78661381   78602026   78759506   78896805

# %%
states.state.unique().tolist()
# Out:
# ['United States',
#  'Northeast',
#  'Midwest',
#  'South',
#  'West',
#  '.Alabama',
#  '.Alaska',
#  '.Arizona',
#  '.Arkansas',
#  '.California',
#  '.Colorado',
#  '.Connecticut',
#  '.Delaware',
#  '.District of Columbia',
#  '.Florida',
#  '.Georgia',
#  '.Hawaii',
#  '.Idaho',
#  '.Illinois',
#  '.Indiana',
#  '.Iowa',
#  '.Kansas',
#  '.Kentucky',
#  '.Louisiana',
#  '.Maine',
#  '.Maryland',
#  '.Massachusetts',
#  '.Michigan',
#  '.Minnesota',
#  '.Mississippi',
#  '.Missouri',
#  '.Montana',
#  '.Nebraska',
#  '.Nevada',
#  '.New Hampshire',
#  '.New Jersey',
#  '.New Mexico',
#  '.New York',
#  '.North Carolina',
#  '.North Dakota',
#  '.Ohio',
#  '.Oklahoma',
#  '.Oregon',
#  '.Pennsylvania',
#  '.Rhode Island',
#  '.South Carolina',
#  '.South Dakota',
#  '.Tennessee',
#  '.Texas',
#  '.Utah',
#  '.Vermont',
#  '.Virginia',
#  '.Washington',
#  '.West Virginia',
#  '.Wisconsin',
#  '.Wyoming']

# %%
#cleaning the data-removing the dots before the name of the states from the above

# %%
states['state'] = states['state'].map(lambda x: x.lstrip('.'))
states.state.unique().tolist()
# Out:
# ['United States',
#  'Northeast',
#  'Midwest',
#  'South',
#  'West',
#  'Alabama',
#  'Alaska',
#  'Arizona',
#  'Arkansas',
#  'California',
#  'Colorado',
#  'Connecticut',
#  'Delaware',
#  'District of Columbia',
#  'Florida',
#  'Georgia',
#  'Hawaii',
#  'Idaho',
#  'Illinois',
#  'Indiana',
#  'Iowa',
#  'Kansas',
#  'Kentucky',
#  'Louisiana',
#  'Maine',
#  'Maryland',
#  'Massachusetts',
#  'Michigan',
#  'Minnesota',
#  'Mississippi',
#  'Missouri',
#  'Montana',
#  'Nebraska',
#  'Nevada',
#  'New Hampshire',
#  'New Jersey',
#  'New Mexico',
#  'New York',
#  'North Carolina',
#  'North Dakota',
#  'Ohio',
#  'Oklahoma',
#  'Oregon',
#  'Pennsylvania',
#  'Rhode Island',
#  'South Carolina',
#  'South Dakota',
#  'Tennessee',
#  'Texas',
#  'Utah',
#  'Vermont',
#  'Virginia',
#  'Washington',
#  'West Virginia',
#  'Wisconsin',
#  'Wyoming']

# %%
#converting the names of the states into abbriveation

# %%
abbr_to_state = {
    "AL": "Alabama", "AK": "Alaska", "AZ": "Arizona", "AR": "Arkansas",
    "CA": "California", "CO": "Colorado", "CT": "Connecticut", "DE": "Delaware",
    "FL": "Florida", "GA": "Georgia", "HI": "Hawaii", "ID": "Idaho",
    "IL": "Illinois", "IN": "Indiana", "IA": "Iowa", "KS": "Kansas",
    "KY": "Kentucky", "LA": "Louisiana", "ME": "Maine", "MD": "Maryland",
    "MA": "Massachusetts", "MI": "Michigan", "MN": "Minnesota", "MS": "Mississippi",
    "MO": "Missouri", "MT": "Montana", "NE": "Nebraska", "NV": "Nevada",
    "NH": "New Hampshire", "NJ": "New Jersey", "NM": "New Mexico", "NY": "New York",
    "NC": "North Carolina", "ND": "North Dakota", "OH": "Ohio", "OK": "Oklahoma",
    "OR": "Oregon", "PA": "Pennsylvania", "RI": "Rhode Island", "SC": "South Carolina",
    "SD": "South Dakota", "TN": "Tennessee", "TX": "Texas", "UT": "Utah",
    "VT": "Vermont", "VA": "Virginia", "WA": "Washington", "WV": "West Virginia",
    "WI": "Wisconsin", "WY": "Wyoming", "AS": "American Samoa"
}

# %%
#the merging step using primary keys

# %%
df['PrimaryKey'] = df['state'].map(abbr_to_state)

# %%
df.head()
# Out:
#        date state  positive  negative  pending  hospitalizedCurrently  \
# 0  20200807    AK    4288.0  264563.0      NaN                   37.0
# 1  20200807    AL   98301.0  651115.0      NaN                 1575.0
# 2  20200807    AR   48039.0  503484.0      NaN                  514.0
# 3  20200807    AS       0.0    1396.0      NaN                    NaN
# 4  20200807    AZ  185053.0  819792.0      NaN                 1772.0
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                     NaN             NaN              NaN
# 1                 11537.0             NaN           1219.0
# 2                  3168.0             NaN              NaN
# 3                     NaN             NaN              NaN
# 4                 19241.0           565.0              NaN
#
#    onVentilatorCurrently  ...  deathIncrease  hospitalizedIncrease  \
# 0                    3.0  ...              0                     0
# ...

# %%
#looking for the data shape

# %%
df.shape
# Out:
# (8697, 42)

# %%
states.shape
# Out:
# (56, 6)

# %%
states.head()
# Out:
#            state    current       2020       2021       2022       2023
# 0  United States  331464948  331526933  332048977  333271411  334914895
# 1      Northeast   57614141   57430477   57243423   57026847   56983517
# 2        Midwest   68987296   68969794   68850246   68783028   68909283
# 3          South  126268529  126465281  127353282  128702030  130125290
# 4           West   78594982   78661381   78602026   78759506   78896805

# %%
#first merge decide which data frame on the right and which one on the left

# %%
first_merge = pd.merge(df, states, left_on='PrimaryKey', right_on='state', how = 'left')

# %%
first_merge.shape
# Out:
# (8697, 48)

# %%
#to review the new columns after merge

# %%
first_merge.columns.tolist()
# Out:
# ['date',
#  'state_x',
#  'positive',
#  'negative',
#  'pending',
#  'hospitalizedCurrently',
#  'hospitalizedCumulative',
#  'inIcuCurrently',
#  'inIcuCumulative',
#  'onVentilatorCurrently',
#  'onVentilatorCumulative',
#  'recovered',
#  'dataQualityGrade',
#  'lastUpdateEt',
#  'dateModified',
#  'checkTimeEt',
#  'death',
#  'hospitalized',
#  'dateChecked',
#  'totalTestsViral',
#  'positiveTestsViral',
#  'negativeTestsViral',
#  'positiveCasesViral',
#  'deathConfirmed',
#  'deathProbable',
#  'fips',
#  'positiveIncrease',
#  'negativeIncrease',
#  'total',
#  'totalTestResults',
#  'totalTestResultsIncrease',
#  'posNeg',
#  'deathIncrease',
#  'hospitalizedIncrease',
#  'hash',
#  'commercialScore',
#  'negativeRegularScore',
#  'negativeScore',
#  'positiveScore',
#  'score',
#  'grade',
#  'PrimaryKey',
#  'state_y',
#  'current',
#  '2020',
#  '2021',
#  '2022',
#  '2023']

# %%
outermerge= pd.merge(df, states, left_on='PrimaryKey', right_on='state', how = 'outer')

# %%
outermerge.shape
# Out:
# (8703, 48)

# %%
outermerge[outermerge.PrimaryKey.isna()]
# Out:
#             date state_x  positive  negative  pending  hospitalizedCurrently  \
# 1388         NaN     NaN       NaN       NaN      NaN                    NaN
# 3561         NaN     NaN       NaN       NaN      NaN                    NaN
# 5427         NaN     NaN       NaN       NaN      NaN                    NaN
# 6210         NaN     NaN       NaN       NaN      NaN                    NaN
# 6835         NaN     NaN       NaN       NaN      NaN                    NaN
# ...          ...     ...       ...       ...      ...                    ...
# 8698  20200309.0      DC       1.0      14.0      3.0                    NaN
# 8699  20200308.0      DC       1.0      10.0      0.0                    NaN
# 8700  20200307.0      DC       0.0       8.0      1.0                    NaN
# 8701  20200306.0      DC       0.0       8.0      1.0                    NaN
# 8702  20200305.0      DC       0.0       6.0      2.0                    NaN
#
# ...

# %%
#merge columns even if no relation between data

# %%
pd.concat
# Out:
# <function pandas.core.reshape.concat.concat(objs: 'Iterable[Series | DataFrame] | Mapping[HashableT, Series | DataFrame]', *, axis: 'Axis' = 0, join: 'str' = 'outer', ignore_index: 'bool' = False, keys: 'Iterable[Hashable] | None' = None, levels=None, names: 'list[HashableT] | None' = None, verify_integrity: 'bool' = False, sort: 'bool' = False, copy: 'bool | None' = None) -> 'DataFrame | Series'>
